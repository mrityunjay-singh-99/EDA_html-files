# %%
import pandas as pd
import numpy as np

# %%
name=["mrityunjay","singh","manish","ankit","reshikesh"]
age=[23,24,21,22,26]
degree=["BBA","Bsc","Msc","Bca","BBA"]
goal=["BM","Docter","scientist","IT engineer","CS"]
data=zip(name,age,degree,goal)
df=pd.DataFrame(data,
                columns=["Name","Age","Degree","Goal"],
                index=["A","B","C","D","E"])
df
# Out:
#          Name  Age Degree         Goal
# A  mrityunjay   23    BBA           BM
# B       singh   24    Bsc       Docter
# C      manish   21    Msc    scientist
# D       ankit   22    Bca  IT engineer
# E   reshikesh   26    BBA           CS

# %%
df["salary"]=[16000,20000,12000,18000,22000]
df
# Out:
#          Name  Age Degree         Goal  column  salary
# A  mrityunjay   23    BBA           BM   16000   16000
# B       singh   24    Bsc       Docter   20000   20000
# C      manish   21    Msc    scientist   12000   12000
# D       ankit   22    Bca  IT engineer   18000   18000
# E   reshikesh   26    BBA           CS   22000   22000

# %%
df1=pd.DataFrame()
df1["number"]=[i for i in range(1,11)]
df1["squre"]=[i**2 for i in range(1,11)]
df1["Z"]=[i**3 for i in range(1,11)]
df1
# Out:
#    number  squre     Z
# 0       1      1     1
# 1       2      4     8
# 2       3      9    27
# 3       4     16    64
# 4       5     25   125
# 5       6     36   216
# 6       7     49   343
# 7       8     64   512
# 8       9     81   729
# 9      10    100  1000

# %%
z=[i**4 for i in range(1,11)]
df1["Z"]=z
df1
# Out:
#    number  squre      Z
# 0       1      1      1
# 1       2      4     16
# 2       3      9     81
# 3       4     16    256
# 4       5     25    625
# 5       6     36   1296
# 6       7     49   2401
# 7       8     64   4096
# 8       9     81   6561
# 9      10    100  10000

# %%
df1["cube"]=[i**3 for i in range(1,11)]
df1
# Out:
#    number  squre      Z  cube
# 0       1      1      1     1
# 1       2      4     16     8
# 2       3      9     81    27
# 3       4     16    256    64
# 4       5     25    625   125
# 5       6     36   1296   216
# 6       7     49   2401   343
# 7       8     64   4096   512
# 8       9     81   6561   729
# 9      10    100  10000  1000

# %%
df1.columns
# Out:
# Index(['number', 'squre', 'Z', 'cube'], dtype='object')

# %%
df1.drop("Z",axis=1)
# Out:
#    number  squre  cube
# 0       1      1     1
# 1       2      4     8
# 2       3      9    27
# 3       4     16    64
# 4       5     25   125
# 5       6     36   216
# 6       7     49   343
# 7       8     64   512
# 8       9     81   729
# 9      10    100  1000

# %%
df1.drop(0)
# Out:
#    number  squre      Z  cube
# 1       2      4     16     8
# 2       3      9     81    27
# 3       4     16    256    64
# 4       5     25    625   125
# 5       6     36   1296   216
# 6       7     49   2401   343
# 7       8     64   4096   512
# 8       9     81   6561   729
# 9      10    100  10000  1000

# %%
df1.drop(5,axis=0)
# Out:
#    number  squre      Z  cube
# 0       1      1      1     1
# 1       2      4     16     8
# 2       3      9     81    27
# 3       4     16    256    64
# 4       5     25    625   125
# 6       7     49   2401   343
# 7       8     64   4096   512
# 8       9     81   6561   729
# 9      10    100  10000  1000

# %%
df2=pd.DataFrame()
l1=[i for i in range(1,10)] # use list comprehension to crea
l2=[i**2 for i in range(1,10)] # use list comprehension to cr
l3=[i**3 for i in range(1,10)] # use list comprehension to creat
df2['X' ]=l1   
df2['Y']=l2
df2['N']=l3
df2
# Out:
#    X   Y    N
# 0  1   1    1
# 1  2   4    8
# 2  3   9   27
# 3  4  16   64
# 4  5  25  125
# 5  6  36  216
# 6  7  49  343
# 7  8  64  512
# 8  9  81  729

# %%
df2=pd.DataFrame()
l1=[i for i in range(1,10)] # use list comprehension to crea
l2=[i**2 for i in range(1,10)] # use list comprehension to cr
l3=[i**3 for i in range(1,10)] # use list comprehension to creat
df2['X' ]=l1   
df2['Y']=l2
df2['N']=l3
df2
# Out:
#    X   Y    N
# 0  1   1    1
# 1  2   4    8
# 2  3   9   27
# 3  4  16   64
# 4  5  25  125
# 5  6  36  216
# 6  7  49  343
# 7  8  64  512
# 8  9  81  729

# %%
df2.drop("X",axis=1,inplace=True)

# %%
df2
# Out:
#     Y    N
# 0   1    1
# 1   4    8
# 2   9   27
# 3  16   64
# 4  25  125
# 5  36  216
# 6  49  343
# 7  64  512
# 8  81  729

# %%
df1
# Out:
#    number  squre      Z  cube
# 0       1      1      1     1
# 1       2      4     16     8
# 2       3      9     81    27
# 3       4     16    256    64
# 4       5     25    625   125
# 5       6     36   1296   216
# 6       7     49   2401   343
# 7       8     64   4096   512
# 8       9     81   6561   729
# 9      10    100  10000  1000

# %%
df1.drop([4,8])
# Out:
#    number  squre      Z  cube
# 0       1      1      1     1
# 1       2      4     16     8
# 2       3      9     81    27
# 3       4     16    256    64
# 5       6     36   1296   216
# 6       7     49   2401   343
# 7       8     64   4096   512
# 9      10    100  10000  1000

# %%
df1.columns[[0,2]]
# Out:
# Index(['number', 'Z'], dtype='object')

# %%
df1["squre"],type(df1["squre"])
# Out:
# (0      1
#  1      4
#  2      9
#  3     16
#  4     25
#  5     36
#  6     49
#  7     64
#  8     81
#  9    100
#  Name: squre, dtype: int64,
#  pandas.core.series.Series)

# %%
df1[["squre","Z"]],
type(df1[["squre","Z"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df1["Z"].values
# Out:
# array([    1,    16,    81,   256,   625,  1296,  2401,  4096,  6561,
#        10000], dtype=int64)

# %%
df1["squre"].values
# Out:
# array([  1,   4,   9,  16,  25,  36,  49,  64,  81, 100], dtype=int64)

# %%
df1.squre
# Out:
# 0      1
# 1      4
# 2      9
# 3     16
# 4     25
# 5     36
# 6     49
# 7     64
# 8     81
# 9    100
# Name: squre, dtype: int64

# %%
df1["squre"]
# Out:
# 0      1
# 1      4
# 2      9
# 3     16
# 4     25
# 5     36
# 6     49
# 7     64
# 8     81
# 9    100
# Name: squre, dtype: int64

# %%
type(df1["squre"].values)
# Out:
# numpy.ndarray

# %%
list1=[1,2,3,4,5]
list2=[10,11,12,13,14]

# %%
np.array(list1)
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.array(list2)
# Out:
# array([10, 11, 12, 13, 14])

# %%
list1+list2
# Out:
# [1, 2, 3, 4, 5, 10, 11, 12, 13, 14]

# %%
np.array(list1)+np.array(list2)
# Out:
# array([11, 13, 15, 17, 19])

# %%
df1["NUMBER"]=df1["number"].values
df1
# Out:
#    number  squre      Z  cube  NUMBER
# 0       1      1      1     1       1
# 1       2      4     16     8       2
# 2       3      9     81    27       3
# 3       4     16    256    64       4
# 4       5     25    625   125       5
# 5       6     36   1296   216       6
# 6       7     49   2401   343       7
# 7       8     64   4096   512       8
# 8       9     81   6561   729       9
# 9      10    100  10000  1000      10

# %%
df1.to_csv("df1data.csv")

# %%
pd.read_csv("df1data.csv")
# Out:
#    Unnamed: 0  number  squre      Z  cube  NUMBER
# 0           0       1      1      1     1       1
# 1           1       2      4     16     8       2
# 2           2       3      9     81    27       3
# 3           3       4     16    256    64       4
# 4           4       5     25    625   125       5
# 5           5       6     36   1296   216       6
# 6           6       7     49   2401   343       7
# 7           7       8     64   4096   512       8
# 8           8       9     81   6561   729       9
# 9           9      10    100  10000  1000      10

# %%
df1.to_csv("df1data.csv",index=False)

# %%
pd.read_csv("df1data.csv")
# Out:
#    number  squre      Z  cube  NUMBER
# 0       1      1      1     1       1
# 1       2      4     16     8       2
# 2       3      9     81    27       3
# 3       4     16    256    64       4
# 4       5     25    625   125       5
# 5       6     36   1296   216       6
# 6       7     49   2401   343       7
# 7       8     64   4096   512       8
# 8       9     81   6561   729       9
# 9      10    100  10000  1000      10

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Mrityunjay\\Desktop\\Data science naresh it\\Self practice'

# %%
df1.to_excel("df1data.xlsx")

# %%
pd.read_excel("df1data.xlsx")
# Out:
#    Unnamed: 0  number  squre      Z  cube  NUMBER
# 0           0       1      1      1     1       1
# 1           1       2      4     16     8       2
# 2           2       3      9     81    27       3
# 3           3       4     16    256    64       4
# 4           4       5     25    625   125       5
# 5           5       6     36   1296   216       6
# 6           6       7     49   2401   343       7
# 7           7       8     64   4096   512       8
# 8           8       9     81   6561   729       9
# 9           9      10    100  10000  1000      10

# %%
df1.to_excel("df1data.xlsx",index=False)

# %%
pd.read_excel("df1data.xlsx")
# Out:
#    number  squre      Z  cube  NUMBER
# 0       1      1      1     1       1
# 1       2      4     16     8       2
# 2       3      9     81    27       3
# 3       4     16    256    64       4
# 4       5     25    625   125       5
# 5       6     36   1296   216       6
# 6       7     49   2401   343       7
# 7       8     64   4096   512       8
# 8       9     81   6561   729       9
# 9      10    100  10000  1000      10

# %%
df
# Out:
#          Name  Age Degree         Goal  column  salary
# A  mrityunjay   23    BBA           BM   16000   16000
# B       singh   24    Bsc       Docter   20000   20000
# C      manish   21    Msc    scientist   12000   12000
# D       ankit   22    Bca  IT engineer   18000   18000
# E   reshikesh   26    BBA           CS   22000   22000

# %%
df1
# Out:
#    number  squre      Z  cube  NUMBER
# 0       1      1      1     1       1
# 1       2      4     16     8       2
# 2       3      9     81    27       3
# 3       4     16    256    64       4
# 4       5     25    625   125       5
# 5       6     36   1296   216       6
# 6       7     49   2401   343       7
# 7       8     64   4096   512       8
# 8       9     81   6561   729       9
# 9      10    100  10000  1000      10

# %%
path=r"C:\Users\Mrityunjay\Desktop\Data science naresh it\Class notes by me\Visadataset.csv"
visa_df=pd.read_csv(path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.shape[1]
# Out:
# 12

# %%
visa_df.shape[0]
# Out:
# 25480

# %%
visa_df.size
# Out:
# 305760

# %%
visa_df.shape[0]*visa_df.shape[1]
# Out:
# 305760

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df.head(20)
# Out:
#    case_id      continent education_of_employee has_job_experience  \
# 0   EZYV01           Asia           High School                  N
# 1   EZYV02           Asia              Master's                  Y
# 2   EZYV03           Asia            Bachelor's                  N
# 3   EZYV04           Asia            Bachelor's                  N
# 4   EZYV05         Africa              Master's                  Y
# 5   EZYV06           Asia              Master's                  Y
# 6   EZYV07           Asia            Bachelor's                  N
# 7   EZYV08  North America            Bachelor's                  Y
# 8   EZYV09           Asia            Bachelor's                  N
# 9   EZYV10         Europe             Doctorate                  Y
# 10  EZYV11           Asia              Master's                  N
# 11  EZYV12           Asia           High School                  Y
# 12  EZYV13           Asia            Bachelor's                  Y
# ...

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
df.head(2)
# Out:
#          Name  Age Degree    Goal  column  salary
# A  mrityunjay   23    BBA      BM   16000   16000
# B       singh   24    Bsc  Docter   20000   20000

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
dict(visa_df.dtypes)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
for i in dict(visa_df.dtypes).keys():
    print(i)
# Out:
# case_id
# continent
# education_of_employee
# has_job_experience
# requires_job_training
# no_of_employees
# yr_of_estab
# region_of_employment
# prevailing_wage
# unit_of_wage
# full_time_position
# case_status

# %%
for i in dict(visa_df.dtypes).values():
    print(i)
# Out:
# object
# object
# object
# object
# object
# int64
# int64
# object
# float64
# object
# object
# object

# %%
for i,j in dict(visa_df.dtypes).items():
    print(i,j)
# Out:
# case_id object
# continent object
# education_of_employee object
# has_job_experience object
# requires_job_training object
# no_of_employees int64
# yr_of_estab int64
# region_of_employment object
# prevailing_wage float64
# unit_of_wage object
# full_time_position object
# case_status object

# %%
o=[]
i1=[]
for i,j in dict(visa_df.dtypes).items():
    if j=="object":
        o.append(j)
    else:
        i1.append(j)
o,i1
# Out:
# ([dtype('O'),
#   dtype('O'),
#   dtype('O'),
#   dtype('O'),
#   dtype('O'),
#   dtype('O'),
#   dtype('O'),
#   dtype('O'),
#   dtype('O')],
#  [dtype('int64'), dtype('int64'), dtype('float64')])

# %%
o=[]
i1=[]
for i,j in dict(visa_df.dtypes).items():
    if j=="object":
        o.append(i)
    else:
        i1.append(i)
o,i1
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
len(o),len(i1)
# Out:
# (9, 3)

# %%
num_df=pd.DataFrame(o,columns=["numerical_column"])
num_df.to_csv("numerical_column_df.csv",index=False)

# %%
cat_df=pd.DataFrame(i1,columns=["categorical_columns"])
cat_df.to_csv("categorical_column_df.csv",index=False)

# %%
keys,datatypes=[],[]
for key,values in dict(visa_df.dtypes).items():
    keys.append(key)
    datatypes.append(values)
pd.DataFrame(zip(keys,datatypes))
# Out:
#                         0        1
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %%
dict1={"name":["manish","mrityunjay","krishan","rakesh"],
      "age":[22,23,35,21]}
pd.DataFrame(dict1)
# Out:
#          name  age
# 0      manish   22
# 1  mrityunjay   23
# 2     krishan   35
# 3      rakesh   21

# %%
d={}
d["keys"]=keys
d["datatype"]=datatypes
pd.DataFrame(d)
# Out:
#                      keys datatype
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %%
visa_df.select_dtypes(include="object").columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude="object").columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isna().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
visa_df.take([100,140,250],axis=0)
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 140  EZYV141      Asia              Master's                  N
# 250  EZYV251      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 140                     N             4390         1944                South
# 250                     N             4280         2004            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 140         88720.29         Year                  N   Certified
# 250         61147.07         Year                  Y   Certified

# %%
visa_df.take([1,3,5],axis=1)
# Out:
#       continent has_job_experience  no_of_employees
# 0          Asia                  N            14513
# 1          Asia                  Y             2412
# 2          Asia                  N            44444
# 3          Asia                  N               98
# 4        Africa                  Y             1082
# ...         ...                ...              ...
# 25475      Asia                  Y             2601
# 25476      Asia                  Y             3274
# 25477      Asia                  Y             1121
# 25478      Asia                  Y             1918
# 25479      Asia                  Y             3195
#
# [25480 rows x 3 columns]

# %%
visa_df.iloc[[100,130,140],[1,2,3]]
# Out:
#          continent education_of_employee has_job_experience
# 100           Asia              Master's                  Y
# 130  South America           High School                  N
# 140           Asia              Master's                  N

# %%
visa_df.iloc[[1,2,3],[2,4,6]]
# Out:
#   education_of_employee requires_job_training  yr_of_estab
# 1              Master's                     N         2002
# 2            Bachelor's                     Y         2008
# 3            Bachelor's                     N         1897

# %%
visa_df.iloc[2001::100,[2,5]]
# Out:
#       education_of_employee  no_of_employees
# 2001             Bachelor's             2583
# 2101               Master's              666
# 2201             Bachelor's             1871
# 2301             Bachelor's             2431
# 2401             Bachelor's              439
# ...                     ...              ...
# 25001              Master's             3501
# 25101            Bachelor's             3788
# 25201            Bachelor's             4250
# 25301              Master's             2391
# 25401            Bachelor's             1114
#
# [235 rows x 2 columns]

# %%
visa_df.iloc[[200,1000,7000],2:]
# Out:
#      education_of_employee has_job_experience requires_job_training  \
# 200              Doctorate                  Y                     N
# 1000              Master's                  N                     N
# 7000            Bachelor's                  N                     N
#
#       no_of_employees  yr_of_estab region_of_employment  prevailing_wage  \
# 200              3282         1979                 West       74441.1100
# 1000             1307         1987            Northeast         665.1571
# 7000              109         1969                South       43866.4000
#
#      unit_of_wage full_time_position case_status
# 200          Year                  Y   Certified
# 1000         Hour                  Y      Denied
# 7000         Year                  Y      Denied

# %%
visa_df.iloc[[1000,5000,7000],:4]
# Out:
#        case_id      continent education_of_employee has_job_experience
# 1000  EZYV1001           Asia              Master's                  N
# 5000  EZYV5001           Asia              Master's                  N
# 7000  EZYV7001  North America            Bachelor's                  N

# %%
visa_df.iloc[10000::100,2::3]
# Out:
#       education_of_employee  no_of_employees  prevailing_wage case_status
# 10000            Bachelor's             1925         51993.82      Denied
# 10100            Bachelor's             2564        178470.63   Certified
# 10200              Master's             4246         90247.32   Certified
# 10300              Master's              987         46369.39   Certified
# 10400            Bachelor's             4555         53388.73      Denied
# ...                     ...              ...              ...         ...
# 25000              Master's             3204         77003.20   Certified
# 25100              Master's             3018         69449.42   Certified
# 25200              Master's              530        159923.98      Denied
# 25300            Bachelor's             3474        179592.42   Certified
# 25400            Bachelor's             1535        103659.75   Certified
#
# [155 rows x 4 columns]

# %%
visa_df[::1000]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 1000    EZYV1001           Asia              Master's                  N
# 2000    EZYV2001           Asia              Master's                  Y
# 3000    EZYV3001           Asia           High School                  Y
# 4000    EZYV4001           Asia             Doctorate                  Y
# 5000    EZYV5001           Asia              Master's                  N
# 6000    EZYV6001         Europe              Master's                  Y
# 7000    EZYV7001  North America            Bachelor's                  N
# 8000    EZYV8001  South America            Bachelor's                  N
# 9000    EZYV9001           Asia              Master's                  N
# 10000  EZYV10001           Asia            Bachelor's                  N
# 11000  EZYV11001           Asia              Master's                  Y
# ...

# %%
visa_df.iloc[:,3]
# Out:
# 0        N
# 1        Y
# 2        N
# 3        N
# 4        Y
#         ..
# 25475    Y
# 25476    Y
# 25477    Y
# 25478    Y
# 25479    Y
# Name: has_job_experience, Length: 25480, dtype: object

# %%
visa_df.iloc[100,:]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visa_df.iloc[[100],:]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa_df.loc['requires_job_training', 'region_of_employment', 'unit_of_wage',
       'full_time_position']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[443], line 1
# ----> 1 visa_df.loc['requires_job_training', 'region_of_employment', 'unit_of_wage',
#       2        'full_time_position']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1371, in _LocIndexer._getitem_tuple(self, tup)
#    1368     return self._getitem_lowerdim(tup)
#    1370 # no multi-index, so validate all of the indexers
# -> 1371 tup = self._validate_tuple_indexer(tup)
#    1373 # ugly hack for GH #836
# ...
